# %%
# wfdb - package for processing physiologic signal and annotation data
import wfdb

# %%
# read a record
record = wfdb.rdrecord(record_name='data/svdb/1.0.0/800', sampfrom=1000 ,sampto=2000)

# %%
# plotting ECG
wfdb.plot_wfdb(record=record, title='Record 800 from svdb')
display(record.__dict__)
# Out:
# {'record_name': '800',
#  'n_sig': 2,
#  'fs': 128,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 1000,
#  'base_time': None,
#  'base_date': None,
#  'comments': [],
#  'sig_name': ['ECG1', 'ECG2'],
#  'p_signal': array([[-0.005,  0.015],
#         [ 0.145, -0.125],
#         [ 0.545, -0.095],
#         ...,
#         [ 0.255, -0.065],
#         [ 0.165, -0.085],
#         [ 0.085, -0.125]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['800.dat', '800.dat'],
#  'fmt': ['212', '212'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [None, None],
#  'adc_gain': [200.0, 200.0],
#  'baseline': [0, 0],
#  'units': ['mV', 'mV'],
#  'adc_res': [10, 10],
#  'adc_zero': [0, 0],
#  'init_value': [-1, 3],
#  'checksum': [57778, 46422],
#  'block_size': [0, 0]}
